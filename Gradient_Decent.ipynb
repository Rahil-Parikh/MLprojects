# %%
e1=[3,0];
e2=[4,0];


for i in range(30):
  d1=2*e1[0]
  d2=2*e2[0]
  
  e1[1]=e1[0]-0.1*d1
  e2[1]=e2[0]-0.1*d2
  
  e1[0]=e1[1]
  e2[0]=e2[1]
  J=e1[0]*e1[0] + e2[0]*e2[0] +4 
  print(e1,e2,J)
# Out:
# [2.4, 2.4] [3.2, 3.2] 20.0
# [1.7999999999999998, 1.7999999999999998] [2.4000000000000004, 2.4000000000000004] 13.0
# [1.3199999999999998, 1.3199999999999998] [1.7600000000000002, 1.7600000000000002] 8.84
# [0.9599999999999999, 0.9599999999999999] [1.2800000000000002, 1.2800000000000002] 6.5600000000000005
# [0.696, 0.696] [0.9280000000000002, 0.9280000000000002] 5.3456
# [0.504, 0.504] [0.6720000000000002, 0.6720000000000002] 4.7056000000000004
# [0.3648, 0.3648] [0.4864000000000001, 0.4864000000000001] 4.369664
# [0.264, 0.264] [0.3520000000000001, 0.3520000000000001] 4.1936
# [0.19104, 0.19104] [0.25472000000000006, 0.25472000000000006] 4.10137856
# [0.13823999999999997, 0.13823999999999997] [0.18432000000000004, 0.18432000000000004] 4.05308416
# [0.10003199999999998, 0.10003199999999998] [0.13337600000000002, 0.13337600000000002] 4.0277955584
# [0.07238399999999999, 0.07238399999999999] [0.09651200000000001, 0.09651200000000001] 4.0145540096
# ...

# %%
e1=5;
e2=5;

d1=2*e1+4
d2=2*e2-6


for i in range(5):
  d1=2*e1+4
  d2=2*e2-6
  e1=e1-0.3*d1
  e2=e2-0.3*d2
  J=e1** + e2** +4*e1-6*e2-7
  print(e1,e2,J)
# Out:
# 0.7999999999999998 3.8 -29.799999999999997
# -0.8800000000000001 3.32 (-26.919999996668974+1.5827161863505358e-07j)
# -1.552 3.128 (-1.9612257352581437e+18+2.1666782621142244e+18j)
# -1.8208 3.0512 (3.396298908376863e+22-5.630210342321887e+22j)
# -1.92832 3.02048 (7.788721492198726e+23+7.068985385319841e+23j)
