# %%
# !git clone https://github.com/pjreddie/darknet.git

# %cd darknet

# !make

# !mkdir -p obj

# %%
# !rm -R darknet/YOLO-Face-detection

# %%
#To check if Gpu is working
import tensorflow as tf
tf.test.gpu_device_name()

# %%
# !./darknet

# %%
# %cd ..

# %%
#installing cuda
#https://stackoverflow.com/questions/50560395/how-to-install-cuda-in-google-colab-gpus
# !wget https://developer.nvidia.com/compute/cuda/9.2/Prod/local_installers/cuda-repo-ubuntu1604-9-2-local_9.2.88-1_amd64 -O cuda-repo-ubuntu1604-9-2-local_9.2.88-1_amd64.deb
# !dpkg -i cuda-repo-ubuntu1604-9-2-local_9.2.88-1_amd64.deb
# !apt-key add /var/cuda-repo-9-2-local/7fa2af80.pub
# !apt-get update
# !apt-get install cuda

# %%
# !pip install mxnet-cu92

# %%
 # !sudo apt-get install python-opencv

# %%
import cv2
#%cd ../content/darknet
# !ls
# !make
# !./darknet imtest data/eagle.jpg
# Out:
# backup						   Gray.jpg	  LICENSE.mit
# C1.jpg						   IMAG8182.jpg   LICENSE.v1
# C2.jpg						   include	  Makefile
# C3.jpg						   libdarknet.a   obj
# C4.jpg						   libdarknet.so  Original.jpg
# cfg						   LICENSE	  python
# cuda-repo-ubuntu1604-9-2-local_9.2.88-1_amd64.deb  LICENSE.fuck   README.md
# darknet						   LICENSE.gen	  results
# data						   LICENSE.gpl	  scripts
# examples					   LICENSE.meta   src
# make: Nothing to be done for 'all'.
# L2 Norm: 371.498230
# Unable to init server: Could not connect: Connection refused
#
# (Original:12646): Gtk-WARNING **: 11:11:56.151: cannot open display:

# %%
import os
os.environ['PATH'] += ':/usr/local/cuda/bin'

# %%
#Installing compilers
# !apt install gcc-5 g++-5 -y

# %%
# !ln -s /usr/bin/gcc-5 /usr/local/cuda/bin/gcc 
# !ln -s /usr/bin/g++-5 /usr/local/cuda/bin/g++

# %%
import os
os.environ['PATH'] += ':/usr/local/cuda/bin'

# %%
#Changing the variables to include OpenCV and GPU in the Makefile
% cd ../darknet
# !sed -i 's/OPENCV=0/OPENCV=1/g' Makefile
# !sed -i 's/GPU=0/GPU=1/g' Makefile
# !sed -i 's/CUDNN=1/CUDNN=0/g' Makefile
# Out:
# /content/darknet

# %%
# And this is how our Makefile looks now
# Check if OPENCV = 1 and GPU = 1
#%cd darknet
# !cat Makefile

# %%
# Apparently we need to install this so that OpenCV can work without any issues
# when we are making the file
# !apt-get install libopencv-dev

# %%
#Running make!
# !make
# Out:
# make: Nothing to be done for 'all'.

# %%
# Downloading YOLO weights
# !pwd
# %cd darknet

# !wget https://pjreddie.com/media/files/yolov3.weights
# Out:
# /content
# /content/darknet
# --2019-03-10 11:16:53--  https://pjreddie.com/media/files/yolov3.weights
# Resolving pjreddie.com (pjreddie.com)... 128.208.3.39
# Connecting to pjreddie.com (pjreddie.com)|128.208.3.39|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 248007048 (237M) [application/octet-stream]
# Saving to: ‘yolov3.weights’
#
# yolov3.weights      100%[===================>] 236.52M  22.5MB/s    in 12s
#
# 2019-03-10 11:17:05 (20.5 MB/s) - ‘yolov3.weights’ saved [248007048/248007048]

# %%
# !sudo apt-get install cuda-compat-10.0
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# Note, selecting 'cuda-compat-10-0' for regex 'cuda-compat-10.0'
# cuda-compat-10-0 is already the newest version (410.104-1).
# The following packages were automatically installed and are no longer required:
#   cuda-10-0 cuda-demo-suite-10-0 cuda-documentation-10-0 cuda-nsight-10-0
#   cuda-nsight-compute-10-0 cuda-nvvp-10-0 cuda-runtime-10-0 cuda-samples-10-0
#   cuda-toolkit-10-0 cuda-tools-10-0 cuda-visual-tools-10-0
#   libnvidia-common-410
# Use 'sudo apt autoremove' to remove them.
# 0 upgraded, 0 newly installed, 0 to remove and 37 not upgraded.

# %%
# !ls
# %cd content/darknet

# !./darknet detect cfg/yolov3.cfg yolov3.weights IMAG8182.jpg
# Out:
# bin   content  dev  home  lib32  media	opt   root  sbin  swift  tmp	usr
# boot  datalab  etc  lib   lib64  mnt	proc  run   srv   sys	 tools	var
# /content/darknet
# layer     filters    size              input                output
#     0 conv     32  3 x 3 / 1   608 x 608 x   3   ->   608 x 608 x  32  0.639 BFLOPs
#     1 conv     64  3 x 3 / 2   608 x 608 x  32   ->   304 x 304 x  64  3.407 BFLOPs
#     2 conv     32  1 x 1 / 1   304 x 304 x  64   ->   304 x 304 x  32  0.379 BFLOPs
#     3 conv     64  3 x 3 / 1   304 x 304 x  32   ->   304 x 304 x  64  3.407 BFLOPs
#     4 res    1                 304 x 304 x  64   ->   304 x 304 x  64
#     5 conv    128  3 x 3 / 2   304 x 304 x  64   ->   152 x 152 x 128  3.407 BFLOPs
#     6 conv     64  1 x 1 / 1   152 x 152 x 128   ->   152 x 152 x  64  0.379 BFLOPs
#     7 conv    128  3 x 3 / 1   152 x 152 x  64   ->   152 x 152 x 128  3.407 BFLOPs
#     8 res    5                 152 x 152 x 128   ->   152 x 152 x 128
# ...

# %%
# !nvidia-smi
# Out:
# Sun Mar 10 10:36:06 2019
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 410.79       Driver Version: 410.79       CUDA Version: 10.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla K80           Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   34C    P8    31W / 149W |      0MiB / 11441MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# ...

# %%
import matplotlib.pyplot as plt
img = plt.imread("predictions.jpg")
plt.imshow(img)
plt.grid(False)
plt.axis('off')
# !pwd
# Out:
# /content/darknet

# %%
# Out:
# /content

# %%
# !cd YOLO-Face-detection

# %%
# !cp YOLO-Face-detection/Makefile darknet

# %%
# !cp YOLO-Face-detection/src/* darknet/src/

# %%
# %cd darknet
# Out:
# /content/darknet

# %%
# !make
# Out:
# gcc  -DOPENCV `pkg-config --cflags opencv`  -DGPU -I/usr/local/cuda/include/ -DCUDNN  -Wall -Wfatal-errors  -Ofast -DOPENCV -DGPU -DCUDNN -c ./src/gemm.c -o obj/gemm.o
# ./src/gemm.c: In function ‘time_ongpu’:
# ./src/gemm.c:246:9: warning: ‘cudaThreadSynchronize’ is deprecated [-Wdeprecated-declarations]
#          cudaThreadSynchronize();
#          ^
# In file included from /usr/local/cuda/include/cuda_runtime.h:96:0,
#                  from ./src/cuda.h:10,
#                  from ./src/gemm.c:3:
# /usr/local/cuda/include/cuda_runtime_api.h:955:57: note: declared here
#  extern __CUDA_DEPRECATED __host__ cudaError_t CUDARTAPI cudaThreadSynchronize(void);
#                                                          ^
# gcc  -DOPENCV `pkg-config --cflags opencv`  -DGPU -I/usr/local/cuda/include/ -DCUDNN  -Wall -Wfatal-errors  -Ofast -DOPENCV -DGPU -DCUDNN -c ./src/utils.c -o obj/utils.o
# ./src/utils.c: In function ‘fgetl’:
# ...

# %%
# !cd ..

# !git clone https://github.com/dannyblueliu/YOLO-Face-detection.git
# Out:
# Cloning into 'YOLO-Face-detection'...
# remote: Enumerating objects: 1025, done.
# remote: Total 1025 (delta 0), reused 0 (delta 0), pack-reused 1025
# Receiving objects: 100% (1025/1025), 552.25 KiB | 1.62 MiB/s, done.
# Resolving deltas: 100% (358/358), done.

# %%
# %cd darknet
# Out:
# /content/darknet

# %%
# !./darknet imtest cfg/yolo-face.cfg yolo-face_final.weights dont_show IMAG8182.jpg
# Out:
# Cannot load image "cfg/yolo-face.cfg"
# L2 Norm: 0.000000
# Unable to init server: Could not connect: Connection refused
#
# (Original:12902): Gtk-WARNING **: 12:16:03.742: cannot open display:

# %%
# !git init Detection
# Out:
# Initialized empty Git repository in /content/Detection/.git/

# %%
# !git remote add origin https://github.com/Rahil-Parikh/Image_Recognition.git

# %%
# !git push --set
# Out:
# fatal: The current branch master has no upstream branch.
# To push the current branch and set the remote as upstream, use
#
#     git push --set-upstream origin master
